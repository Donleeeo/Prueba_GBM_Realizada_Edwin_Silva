# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import openpyxl
from keras.models import load_model
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# #Cargar Modelo

# %%
modelo_cargado = load_model('/content/drive/MyDrive/Colab Notebooks/Prueba GBM/Ejercicio 4 /modelo_keras.h5')

# %%
Path = '/content/drive/MyDrive/Colab Notebooks/Prueba GBM/Ejercicio 4 /Data_Prueba.xlsx'
Prueba_Id = pd.read_excel(Path)
Prueba = Prueba.drop('customer_id', axis=1)

# %%
Prueba.head()
# Out:
#    Frecuencia  Total_Gastado  Max_Gastado  Dia_Ultima_Compra  \
# 0          15           1012          105                 15
# 1          20           1490           98                 20
# 2          19           1432          105                 19
# 3          22           1659          104                 22
# 4          13            857          105                 13
#
#    Promedio_Dias_Compra
# 0             50.873523
# 1             54.685812
# 2             73.693168
# 3             55.413425
# 4            107.361010

# %%
scaler = StandardScaler()
Data_Scaled = scaler.fit_transform(Prueba)

# %% [markdown]
# # Predicción

# %%
predicciones = modelo_cargado.predict(Data_Scaled)
clases_predichas_indices = np.argmax(predicciones, axis=1)
print(clases_predichas_indices)

etiquetas = ['Bajo', 'Medio', 'Alto']

# Mapear índices a etiquetas
clases_predichas_etiquetas = [etiquetas[i] for i in clases_predichas_indices]

# Imprimir las etiquetas predichas
print(clases_predichas_etiquetas)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [1 0 2 0 1]
# ['Medio', 'Bajo', 'Alto', 'Bajo', 'Medio']
